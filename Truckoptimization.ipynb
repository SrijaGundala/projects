# %%
import matplotlib.pyplot as plt
import heapq
from collections import defaultdict
from itertools import combinations
#Main
# Define the truck dimensions and capacity
TRUCK_WIDTH = 4.65
TRUCK_LENGTH = 33.800
TRUCK_CAPACITY = 8

# Define car types and their dimensions (length and width)
car_types = {
    "Grand i10": (3.8, 1.66),
    "i20": (3.99, 1.75),
    "Aura/Xcent": (4.01, 1.68),
    "Creta": (4.27, 1.78),
    "Ioniq": (4.47, 1.82),
    "Exter": (3.81, 1.71),
    "Verna": (4.44, 1.73),
    "Tuscon": (4.48, 1.85),
    "Venue": (3.995, 1.77),
    "Kona": (4.18, 1.8),
    "New Verna": (4.44, 1.73),
    "Santro": (3.61, 1.64),
    "Elantra": (4.62, 1.8),
    "Alcazar": (4.5, 1.79)
}

def generate_patterns(car_types, max_length, max_capacity):
    patterns = []
    car_list = [(car, length) for car, (length, width) in car_types.items()]

    # Generate all unique combinations of cars
    for r in range(1, max_capacity + 1):
        for combo in combinations(car_list, r):
            combo_length = sum(length for car, length in combo)
            if combo_length <= max_length:
                pattern = [car for car, length in combo]
                patterns.append((combo_length, pattern))
    
    # Sort patterns by length in descending order
    patterns.sort(reverse=True, key=lambda x: x[0])
    return patterns

def arrange_cars_in_trucks(car_types, quantities):
    patterns = generate_patterns(car_types, TRUCK_LENGTH, TRUCK_CAPACITY)
    
    # Priority queue for trucks based on remaining length
    truck_queue = []
    heapq.heappush(truck_queue, (-TRUCK_LENGTH, 0, []))  # (negative remaining length, truck_id, list of cars)
    current_truck_id = 0

    for car_type, (car_length, car_width) in sorted(car_types.items(), key=lambda x: -x[1][0]):
        quantity = quantities[car_type]

        while quantity > 0:
            remaining_length, truck_id, cars_in_truck = heapq.heappop(truck_queue)

            if len(cars_in_truck) < TRUCK_CAPACITY and -remaining_length >= car_length:
                cars_in_truck.append(car_type)
                remaining_length += car_length  # since remaining_length is stored as negative
                quantity -= 1
            else:
                if len(cars_in_truck) == TRUCK_CAPACITY or -remaining_length < car_length:
                    current_truck_id += 1
                    heapq.heappush(truck_queue, (-TRUCK_LENGTH, current_truck_id, []))

            heapq.heappush(truck_queue, (remaining_length, truck_id, cars_in_truck))

    trucks = defaultdict(list)
    while truck_queue:
        remaining_length, truck_id, cars_in_truck = heapq.heappop(truck_queue)
        trucks[truck_id].extend(cars_in_truck)

    for truck_id in sorted(trucks):
        print(f"Truck {truck_id + 1}: {trucks[truck_id]}")

    return patterns

def plot_solution(all_rects, car_types):
    # Plot
    plt.figure(figsize=(33.805, 4.65))
    # Loop all rect
    for rect in all_rects:
        b, x, y, w, h, rid = rect
        x1, x2, x3, x4, x5 = x, x + w, x + w, x, x
        y1, y2, y3, y4, y5 = y, y, y + h, y + h, y

        # Assign color based on car type
        if w == car_types["Grand i10"][0] and h == car_types["Grand i10"][1]:
            color = '--k'
        elif w == car_types["i20"][0] and h == car_types["i20"][1]:
            color = '--b'
        elif w == car_types["Aura/Xcent"][0] and h == car_types["Aura/Xcent"][1]:
            color = '--g'
        elif w == car_types["Creta"][0] and h == car_types["Creta"][1]:
            color = '--r'
        # Add more elif statements for other car types
        else:
            color = '--m'  # Default color for other car types

        plt.plot([x1, x2, x3, x4, x5], [y1, y2, y3, y4, y5], color)
    
    plt.show()

if __name__ == "__main__":
    car_types = {
        "Grand i10": (3.8, 1.66),
        "i20": (3.99, 1.75),
        "Aura/Xcent": (4.01, 1.68),
        "Creta": (4.27, 1.78),
        "Ioniq": (4.47, 1.82),
        "Exter": (3.81, 1.71),
        "Verna": (4.44, 1.73),
        "Tuscon": (4.48, 1.85),
        "Venue": (3.995, 1.77),
        "Kona": (4.18, 1.8),
        "New Verna": (4.44, 1.73),
        "Santro": (3.61, 1.64),
        "Elantra": (4.62, 1.8),
        "Alcazar": (4.5, 1.79)
    }

    quantities = {
        "Grand i10": 110,
        "i20": 59,
        "Aura/Xcent": 16,
        "Creta": 55,
        "Ioniq": 0,
        "Exter": 66,
        "Verna": 0,
        "Tuscon": 0,
        "Venue": 56,
        "Kona": 0,
        "New Verna": 24,
        "Santro": 0,
        "Elantra": 0,
        "Alcazar": 6
    }

    patterns = arrange_cars_in_trucks(car_types, quantities)
    # print("Unique patterns:")
    # for length, pattern in patterns:
    #     print(f"Length: {length}, Pattern: {pattern}")
# Out:
# Truck 1: ['Alcazar', 'Alcazar', 'Alcazar', 'Alcazar', 'Alcazar', 'Alcazar', 'New Verna']
# Truck 2: ['New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna']
# Truck 3: ['New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna']
# Truck 4: ['New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna', 'New Verna']
# Truck 5: ['New Verna', 'New Verna', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta']
# Truck 6: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 7: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 8: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 9: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 10: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 11: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 12: ['Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Creta', 'Exter']
# Truck 13: ['Creta', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent']
# Truck 14: ['Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent', 'Aura/Xcent']
# Truck 15: ['Aura/Xcent', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 16: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 17: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 18: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 19: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 20: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 21: ['Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue', 'Venue']
# Truck 22: ['Venue', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 23: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 24: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 25: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 26: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 27: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 28: ['i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20', 'i20']
# Truck 29: ['i20', 'i20', 'i20', 'i20', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 30: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 31: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 32: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 33: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 34: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 35: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter']
# Truck 36: ['Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Exter', 'Grand i10']
# Truck 37: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 38: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 39: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 40: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 41: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 42: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 43: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 44: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 45: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 46: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 47: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 48: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 49: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']
# Truck 50: ['Grand i10', 'Grand i10', 'Grand i10', 'Grand i10', 'Grand i10']

# %%
import matplotlib.pyplot as plt
import heapq
from collections import defaultdict
from itertools import combinations

# Define the truck dimensions and capacity
TRUCK_WIDTH = 4.65
TRUCK_LENGTH = 33.805
TRUCK_CAPACITY = 8

# Define car types and their dimensions (length and width)
car_types = {
    "Grand i10": (3.8, 1.66),
    "i20": (3.99, 1.75),
    "Aura/Xcent": (4.01, 1.68),
    "Creta": (4.27, 1.78),
    "Ioniq": (4.47, 1.82),
    "Exter": (3.81, 1.71),
    "Verna": (4.44, 1.73),
    "Tuscon": (4.48, 1.85),
    "Venue": (3.995, 1.77),
    "Kona": (4.18, 1.8),
    "New Verna": (4.44, 1.73),
    "Santro": (3.61, 1.64),
    "Elantra": (4.62, 1.8),
    "Alcazar": (4.5, 1.79)
}

def generate_patterns(car_types, max_length, max_capacity):
    patterns = []
    car_list = [(car, length) for car, (length, width) in car_types.items()]

    # Generate all unique combinations of cars
    for r in range(1, max_capacity + 1):
        for combo in combinations(car_list, r):
            combo_length = sum(length for car, length in combo)
            if combo_length <= max_length:
                pattern = [car for car, length in combo]
                patterns.append((combo_length, pattern))
    
    # Sort patterns by length in descending order
    patterns.sort(reverse=True, key=lambda x: x[0])
    return patterns

def arrange_cars_in_trucks(car_types, quantities):
    patterns = generate_patterns(car_types, TRUCK_LENGTH, TRUCK_CAPACITY)
    
    # Priority queue for trucks based on remaining length
    truck_queue = []
    heapq.heappush(truck_queue, (-TRUCK_LENGTH, 0, []))  # (negative remaining length, truck_id, list of cars)
    current_truck_id = 0

    for car_type, (car_length, car_width) in sorted(car_types.items(), key=lambda x: -x[1][0]):
        quantity = quantities[car_type]

        while quantity > 0:
            remaining_length, truck_id, cars_in_truck = heapq.heappop(truck_queue)

            if len(cars_in_truck) < TRUCK_CAPACITY and -remaining_length >= car_length:
                cars_in_truck.append(car_type)
                remaining_length += car_length  # since remaining_length is stored as negative
                quantity -= 1
            else:
                if len(cars_in_truck) == TRUCK_CAPACITY or -remaining_length < car_length:
                    current_truck_id += 1
                    heapq.heappush(truck_queue, (-TRUCK_LENGTH, current_truck_id, []))

            heapq.heappush(truck_queue, (remaining_length, truck_id, cars_in_truck))

    trucks = defaultdict(list)
    while truck_queue:
        remaining_length, truck_id, cars_in_truck = heapq.heappop(truck_queue)
        trucks[truck_id].extend(cars_in_truck)

    for truck_id in sorted(trucks):
        print(f"Truck {truck_id + 1}: {trucks[truck_id]}")

    return patterns

def plot_solution(car_types, trucks):
    # Plot
    plt.figure(figsize=(33.805, 4.65))
    color_map = {
        "Grand i10": '--k',
        "i20": '--b',
        "Aura/Xcent": '--g',
        "Creta": '--r',
        "Ioniq": '--c',
        "Exter": '--m',
        "Verna": '--y',
        "Tuscon": '--k',
        "Venue": '--b',
        "Kona": '--g',
        "New Verna": '--r',
        "Santro": '--c',
        "Elantra": '--m',
        "Alcazar": '--y'
    }
    
    x_offset = 0
    y_offset = 0
    truck_counter = 0
    
    for truck_id in sorted(trucks):
        for car in trucks[truck_id]:
            car_length, car_width = car_types[car]
            x1, x2, x3, x4, x5 = x_offset, x_offset + car_length, x_offset + car_length, x_offset, x_offset
            y1, y2, y3, y4, y5 = y_offset, y_offset, y_offset + car_width, y_offset + car_width, y_offset

            plt.plot([x1, x2, x3, x4, x5], [y1, y2, y3, y4, y5], color_map[car])

            y_offset += car_width
            if y_offset + car_width > TRUCK_WIDTH:
                y_offset = 0
                x_offset += car_length

        truck_counter += 1
        if truck_counter % 2 == 0:
            x_offset = 0
            y_offset = 0

    plt.show()

if __name__ == "__main__":
    quantities = {
        "Grand i10": 2,
        "i20": 2,
        "Aura/Xcent": 2,
        "Creta": 2,
        "Ioniq": 2,
        "Exter": 2,
        "Verna": 2,
        "Tuscon": 2,
        "Venue": 2,
        "Kona": 2,
        "New Verna": 2,
        "Santro": 2,
        "Elantra": 2,
        "Alcazar": 2
    }

    patterns = arrange_cars_in_trucks(car_types, quantities)
    # print("Unique patterns:")
    # for length, pattern in patterns:
    #     print(f"Length: {length}, Pattern: {pattern}")

    # Example usage of plot_solution
    # arrange the cars in trucks and visualize
    # trucks = arrange_cars_in_trucks(car_types, quantities)
    # plot_solution(car_types, trucks)
# Out:
# Truck 1: ['Elantra', 'Elantra', 'Alcazar', 'Alcazar', 'Tuscon', 'Tuscon', 'Ioniq']
# Truck 2: ['Ioniq', 'Verna', 'Verna', 'New Verna', 'New Verna', 'Creta', 'Creta']
# Truck 3: ['Kona', 'Kona', 'Aura/Xcent', 'Aura/Xcent', 'Venue', 'Venue', 'i20', 'i20']
# Truck 4: ['Exter', 'Exter', 'Grand i10', 'Grand i10', 'Santro', 'Santro']

# %%
import pandas as pd
import sqlite3

# Function to replace spaces with underscores in column names
def process_column_names(df):
    df.columns = df.columns.str.replace(' ', '_')
    return df

# Read Excel file
file_path = 'Shipment.xlsx'  # Change this to the path of your Excel file
df = pd.read_excel(file_path)
# Process column names
df = process_column_names(df)

# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('shipment_details.db')

# Store data into SQLite table
table_name = 'ShipmentDetails'
df.to_sql(table_name, conn, if_exists='replace', index=False)

# Verify the data stored in the database
cursor = conn.cursor()
cursor.execute(f"SELECT * FROM {table_name} LIMIT 5")
print(cursor.fetchall())

# Close the connection
conn.close()
# Out:
# [(1069, '2021-01-01', 'FHC', 'E10', 90000), (1069, '2021-01-01', 'S5F', 'E10', 90000), (1069, '2021-01-01', 'C4A', 'E10', 90000), (1069, '2021-01-01', 'B4F', 'E10', 90000), (1069, '2021-01-01', 'HQW', 'E10', 90000)]

# %%
import sqlite3
import pandas as pd

def read_table_to_dataframe(db_name, table_name):
    """
    Reads all columns from the specified table in the SQLite database into a Pandas DataFrame.

    Parameters:
    db_name (str): The name of the SQLite database file.
    table_name (str): The name of the table to read data from.

    Returns:
    DataFrame: A Pandas DataFrame containing the table data.
    """
    try:
        # Connect to the SQLite database
        conn = sqlite3.connect(db_name)

        # Read the table into a DataFrame
        df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

        return df

    except sqlite3.Error as e:
        print(f"Error reading data from SQLite table: {e}")
        return pd.DataFrame()

    finally:
        # Close the database connection
        if conn:
            conn.close()

# Example usage
db_name = 'shipment_details.db'
table_name = 'ShipmentDetails'
df = read_table_to_dataframe(db_name, table_name)
df
# Out:
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 0          1069  2021-01-01        FHC       E10       90000
# 1          1069  2021-01-01        S5F       E10       90000
# 2          1069  2021-01-01        C4A       E10       90000
# 3          1069  2021-01-01        B4F       E10       90000
# 4          1069  2021-01-01        HQW       E10       90000
# ..          ...         ...        ...       ...         ...
# 995        1299  2022-01-01        FHB       E10       90000
# 996        1299  2022-01-01        HRW       E12      900000
# 997        1299  2022-01-01        6IW       E12      900000
# 998        1299  2022-01-01        6IW       E12      900000
# 999        1299  2022-01-01        HQF       E12      900000
#
# [1000 rows x 5 columns]

# %%
grouped = df.groupby('Shipment_n')

# Displaying the groups
for name, group in grouped:
    print(f"Group: {name}")
    print(group)
# Out:
# Group: 1024
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 917        1024  2022-01-01        FHW  Bangaluru       99999
# 918        1024  2022-01-01        HQF  Bangaluru       99999
# 919        1024  2022-01-01        0YF  Bangaluru       99999
# 920        1024  2022-01-01        HRW  Bangaluru       99999
# 921        1024  2022-01-01        HOW  Bangaluru       99999
# 922        1024  2023-01-01        9ML  Bangaluru       99999
# 923        1024  2023-01-01        FHC  Bangaluru       99999
# Group: 1032
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 70        1032  2022-01-01        6IW        AP       79990
# 71        1032  2022-01-01        FHY        AP       79990
# 72        1032  2022-01-01        FHB        TS      800000
# 73        1032  2023-01-01        SPW        TS      800000
# 74        1032  2023-01-01        FHC        TS      800000
# 75        1032  2023-01-01        FHY        TS      800000
# 76        1032  2023-01-01        C4A        AP       79990
# Group: 1069
#    Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 0        1069  2021-01-01        FHC       E10       90000
# 1        1069  2021-01-01        S5F       E10       90000
# 2        1069  2021-01-01        C4A       E10       90000
# 3        1069  2021-01-01        B4F       E10       90000
# 4        1069  2021-01-01        HQW       E10       90000
# 5        1069  2021-01-01        HRW       E10       90000
# 6        1069  2021-01-01        HQF       E11        9000
# Group: 1132
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 476        1132  2022-01-01        0YF        C2       23170
# 477        1132  2022-01-01        HQA        C1       23120
# 478        1132  2022-01-01        SVA        C1       23120
# 479        1132  2022-01-01        FHC        C1       23120
# 480        1132  2022-01-01        SPW        C1       23120
# 481        1132  2022-01-01        FHC        C1       23120
# 482        1132  2022-01-01        SPW        C1       23120
# Group: 1163
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 686        1163  2022-01-01        9ML        C1                23120
# 687        1163  2022-01-01        6IW        C2                23170
# 688        1163  2022-01-01        S5F        C3                   10
# 689        1163  2022-01-01        S5F        C4  1000000000000000000
# 690        1163  2022-01-01        HRW        C5                 2342
# 691        1163  2022-01-01        HRW        C6                23420
# 692        1163  2022-01-01        H6F        C7                  230
# Group: 1164
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 413        1164  2023-01-01        HQW  Bangaluru       99999
# 414        1164  2023-01-01        FHY  Bangaluru       99999
# 415        1164  2023-01-01        FHC  Bangaluru       99999
# 416        1164  2023-01-01        S5F  Bangaluru       99999
# 417        1164  2023-01-01        HRW  Bangaluru       99999
# 418        1164  2023-01-01        B4F  Bangaluru       99999
# 419        1164  2023-01-01        HOW  Bangaluru       99999
# Group: 1171
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 987        1171  2021-01-01        S5F       E11        9000
# 988        1171  2021-01-01        SPW       E10       90000
# 989        1171  2021-01-01        FHC       E10       90000
# 990        1171  2021-01-01        0YF       E10       90000
# 991        1171  2021-01-01        6IW       E10       90000
# 992        1171  2021-01-01        B4F       E10       90000
# 993        1171  2021-01-01        0YF       E10       90000
# Group: 1299
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 994        1299  2022-01-01        FHB       E10       90000
# 995        1299  2022-01-01        FHB       E10       90000
# 996        1299  2022-01-01        HRW       E12      900000
# 997        1299  2022-01-01        6IW       E12      900000
# 998        1299  2022-01-01        6IW       E12      900000
# 999        1299  2022-01-01        HQF       E12      900000
# Group: 1321
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 273        1321  2022-01-01        6IW   CHENNAI      100000
# 274        1321  2022-01-01        C4A        C3          10
# 275        1321  2022-01-01        S5F        C1       23120
# 276        1321  2022-01-01        B4F        C1       23120
# 277        1321  2022-01-01        FHC        C1       23120
# 278        1321  2022-01-01        S5F        C2       23170
# 279        1321  2022-01-01        SVA        C2       23170
# Group: 1351
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 224        1351  2021-01-01        HOW  Bangaluru       99999
# 225        1351  2021-01-01        FHW  Bangaluru       99999
# 226        1351  2021-01-01        FHW  Bangaluru       99999
# 227        1351  2021-01-01        FHC  Bangaluru       99999
# 228        1351  2021-01-01        FHW  Bangaluru       99999
# 229        1351  2021-01-01        HQF  Bangaluru       99999
# 230        1351  2021-01-01        FHC  Bangaluru       99999
# Group: 1580
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 182        1580  2023-01-01        HQA       E10       90000
# 183        1580  2023-01-01        FHB       E10       90000
# 184        1580  2023-01-01        FHY       E10       90000
# 185        1580  2023-01-01        S5F       E12      900000
# 186        1580  2023-01-01        SPW       E12      900000
# 187        1580  2023-01-01        HQA       E12      900000
# 188        1580  2023-01-01        6IW       E12      900000
# Group: 1818
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 616        1818  2023-01-01        FHY        C1       23120
# 617        1818  2023-01-01        HQA        C1       23120
# 618        1818  2023-01-01        SPW        C1       23120
# 619        1818  2023-01-01        SPW        C1       23120
# 620        1818  2023-01-01        B4F        C1       23120
# 621        1818  2023-01-01        S5F        C1       23120
# 622        1818  2023-01-01        SPW        C1       23120
# Group: 1893
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 21        1893  2021-01-01        H6F   CHENNAI      100000
# 22        1893  2021-01-01        S5F        C3          10
# 23        1893  2021-01-01        FHB        C1       23120
# 24        1893  2021-01-01        SVA        C1       23120
# 25        1893  2021-01-01        HOW        C1       23120
# 26        1893  2021-01-01        B4F        C2       23170
# 27        1893  2021-01-01        C4A        C2       23170
# Group: 1984
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 833        1984  2023-01-01        6IW   CHENNAI      100000
# 834        1984  2023-01-01        S5F        C3          10
# 835        1984  2023-01-01        C4A        C1       23120
# 836        1984  2023-01-01        S5F        C1       23120
# 837        1984  2023-01-01        SPW        C1       23120
# 838        1984  2023-01-01        B4F        C2       23170
# 839        1984  2023-01-01        B4F        C2       23170
# Group: 1997
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 490        1997  2022-01-01        SVA       E11        9000
# 491        1997  2022-01-01        H6F       E11        9000
# 492        1997  2022-01-01        HOW       E10       90000
# 493        1997  2022-01-01        9ML       E10       90000
# 494        1997  2022-01-01        FHB       E10       90000
# 495        1997  2022-01-01        9ML       E10       90000
# 496        1997  2022-01-01        C4A       E10       90000
# Group: 2083
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 154        2083  2022-01-01        FHY       E11        9000
# 155        2083  2022-01-01        FHB       E11        9000
# 156        2083  2022-01-01        B4F       E10       90000
# 157        2083  2022-01-01        FHW       E10       90000
# 158        2083  2022-01-01        FHW       E10       90000
# 159        2083  2022-01-01        FHY       E10       90000
# 160        2083  2022-01-01        C4A       E10       90000
# Group: 2086
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 770        2086  2021-01-01        H6F       E10       90000
# 771        2086  2021-01-01        HQF       E10       90000
# 772        2086  2021-01-01        9ML       E10       90000
# 773        2086  2021-01-01        HRW       E12      900000
# 774        2086  2021-01-01        HQF       E12      900000
# 775        2086  2021-01-01        FHB       E12      900000
# 776        2086  2021-01-01        C4A       E12      900000
# Group: 2089
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 553        2089  2021-01-01        FHY   jodhpur         700
# 554        2089  2021-01-01        FHY   jodhpur         700
# 555        2089  2021-01-01        FHY    jaipur      700000
# 556        2089  2021-01-01        FHC    Shimla         123
# 557        2089  2021-01-01        HQF   jodhpur         700
# 558        2089  2021-01-01        6IW   jodhpur         700
# 559        2089  2021-01-01        FHW    jaipur      700000
# Group: 2139
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 875        2139  2021-01-01        SVA        AP       79990
# 876        2139  2021-01-01        HQF        AP       79990
# 877        2139  2021-01-01        SPW        TS      800000
# 878        2139  2021-01-01        HRW        TS      800000
# 879        2139  2021-01-01        HOW        TS      800000
# 880        2139  2021-01-01        HOW        TS      800000
# 881        2139  2021-01-01        FHY        AP       79990
# Group: 2170
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 812        2170  2022-01-01        FHW       E10       90000
# 813        2170  2022-01-01        6IW       E10       90000
# 814        2170  2022-01-01        H6F       E10       90000
# 815        2170  2022-01-01        FHC       E10       90000
# 816        2170  2022-01-01        HQW       E10       90000
# 817        2170  2023-01-01        SVA       E10       90000
# 818        2170  2023-01-01        FHW       E11        9000
# Group: 2227
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 196        2227  2023-01-01        FHW        C1       23120
# 197        2227  2023-01-01        FHB        C1       23120
# 198        2227  2023-01-01        9ML        C1       23120
# 199        2227  2023-01-01        B4F        C1       23120
# 200        2227  2023-01-01        C4A        C1       23120
# 201        2227  2023-01-01        S5F        C1       23120
# 202        2227  2023-01-01        HOW        C1       23120
# Group: 2230
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 938        2230  2023-01-01        FHB  Bangaluru       99999
# 939        2230  2023-01-01        FHY  Bangaluru       99999
# 940        2230  2023-01-01        HOW  Bangaluru       99999
# 941        2230  2023-01-01        C4A  Bangaluru       99999
# 942        2230  2023-01-01        9ML  Bangaluru       99999
# 943        2230  2023-01-01        B4F  Bangaluru       99999
# 944        2230  2023-01-01        FHB  Bangaluru       99999
# Group: 2239
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 112        2239  2021-01-01        S5F        C1       23120
# 113        2239  2021-01-01        FHB        C1       23120
# 114        2239  2021-01-01        FHW        C1       23120
# 115        2239  2021-01-01        0YF        C1       23120
# 116        2239  2021-01-01        S5F        C1       23120
# 117        2239  2021-01-01        HQF        C1       23120
# 118        2239  2021-01-01        HQF        C1       23120
# Group: 2316
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 7         2316  2021-01-01        SPW       E11        9000
# 8         2316  2021-01-01        FHB       E11        9000
# 9         2316  2021-01-01        HOW       E10       90000
# 10        2316  2021-01-01        B4F       E10       90000
# 11        2316  2021-01-01        SPW       E10       90000
# 12        2316  2021-01-01        HQA       E10       90000
# 13        2316  2021-01-01        FHW       E10       90000
# Group: 2364
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 903        2364  2022-01-01        FHB       E11        9000
# 904        2364  2022-01-01        S5F       E11        9000
# 905        2364  2022-01-01        HQF       E10       90000
# 906        2364  2022-01-01        HOW       E10       90000
# 907        2364  2022-01-01        FHY       E10       90000
# 908        2364  2022-01-01        9ML       E10       90000
# 909        2364  2022-01-01        FHC       E10       90000
# Group: 2603
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 469        2603  2022-01-01        B4F   jodhpur         700
# 470        2603  2022-01-01        B4F   CHENNAI      100000
# 471        2603  2022-01-01        HQF        C3          10
# 472        2603  2022-01-01        H6F        C1       23120
# 473        2603  2022-01-01        SVA        C1       23120
# 474        2603  2022-01-01        9ML        C1       23120
# 475        2603  2022-01-01        HRW        C2       23170
# Group: 2684
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 700        2684  2022-01-01        B4F   jodhpur         700
# 701        2684  2022-01-01        FHB   jodhpur         700
# 702        2684  2022-01-01        SPW    jaipur      700000
# 703        2684  2022-01-01        FHY    Shimla         123
# 704        2684  2022-01-01        HQA   jodhpur         700
# 705        2684  2022-01-01        HOW   jodhpur         700
# 706        2684  2022-01-01        FHY    jaipur      700000
# Group: 2696
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 595        2696  2022-01-01        FHY       E11        9000
# 596        2696  2022-01-01        HQA       E11        9000
# 597        2696  2022-01-01        FHY       E10       90000
# 598        2696  2022-01-01        S5F       E10       90000
# 599        2696  2022-01-01        SPW       E10       90000
# 600        2696  2022-01-01        SVA       E10       90000
# 601        2696  2022-01-01        FHY       E10       90000
# Group: 2768
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 707        2768  2022-01-01        HRW  Bangaluru       99999
# 708        2768  2022-01-01        B4F  Bangaluru       99999
# 709        2768  2022-01-01        6IW  Bangaluru       99999
# 710        2768  2022-01-01        6IW  Bangaluru       99999
# 711        2768  2022-01-01        S5F  Bangaluru       99999
# 712        2768  2023-01-01        0YF  Bangaluru       99999
# 713        2768  2023-01-01        0YF  Bangaluru       99999
# Group: 2812
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 294        2812  2023-01-01        FHY    jaipur      700000
# 295        2812  2023-01-01        SPW    jaipur      700000
# 296        2812  2023-01-01        HQW   jodhpur         700
# 297        2812  2023-01-01        0YF   jodhpur         700
# 298        2812  2023-01-01        0YF    jaipur      700000
# 299        2812  2023-01-01        C4A    jaipur      700000
# 300        2812  2023-01-01        HQA    jaipur      700000
# Group: 2854
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 784        2854  2022-01-01        9ML        C2       23170
# 785        2854  2022-01-01        FHW        C1       23120
# 786        2854  2022-01-01        SVA        C1       23120
# 787        2854  2022-01-01        SVA        C1       23120
# 788        2854  2022-01-01        HOW        C1       23120
# 789        2854  2022-01-01        HQW        C1       23120
# 790        2854  2022-01-01        6IW        C1       23120
# Group: 2877
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 175        2877  2022-01-01        SPW       E11        9000
# 176        2877  2022-01-01        S5F       E11        9000
# 177        2877  2022-01-01        HQF       E10       90000
# 178        2877  2022-01-01        H6F       E10       90000
# 179        2877  2023-01-01        SVA       E10       90000
# 180        2877  2023-01-01        S5F       E10       90000
# 181        2877  2023-01-01        SPW       E10       90000
# Group: 2928
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 896        2928  2022-01-01        FHC       E10       90000
# 897        2928  2022-01-01        0YF       E10       90000
# 898        2928  2022-01-01        HQA       E10       90000
# 899        2928  2022-01-01        SVA       E10       90000
# 900        2928  2022-01-01        HQA       E10       90000
# 901        2928  2022-01-01        HQW       E10       90000
# 902        2928  2022-01-01        C4A       E11        9000
# Group: 2936
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 238        2936  2021-01-01        HQW        AP       79990
# 239        2936  2021-01-01        SVA        AP       79990
# 240        2936  2021-01-01        HQW        TS      800000
# 241        2936  2021-01-01        HQW        TS      800000
# 242        2936  2021-01-01        HQF        TS      800000
# 243        2936  2021-01-01        HOW        TS      800000
# 244        2936  2021-01-01        S5F        AP       79990
# Group: 2990
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 959        2990  2021-01-01        C4A  Bangaluru       99999
# 960        2990  2021-01-01        S5F  Bangaluru       99999
# 961        2990  2021-01-01        6IW  Bangaluru       99999
# 962        2990  2021-01-01        9ML  Bangaluru       99999
# 963        2990  2021-01-01        0YF  Bangaluru       99999
# 964        2990  2021-01-01        HRW  Bangaluru       99999
# 965        2990  2021-01-01        C4A  Bangaluru       99999
# Group: 3099
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 210        3099  2023-01-01        B4F    jaipur      700000
# 211        3099  2023-01-01        S5F    jaipur      700000
# 212        3099  2023-01-01        HOW   jodhpur         700
# 213        3099  2023-01-01        9ML   jodhpur         700
# 214        3099  2021-01-01        HOW    jaipur      700000
# 215        3099  2021-01-01        H6F    jaipur      700000
# 216        3099  2021-01-01        FHW    jaipur      700000
# Group: 3355
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 343        3355  2021-01-01        FHB       E11        9000
# 344        3355  2021-01-01        0YF       E11        9000
# 345        3355  2021-01-01        SPW       E10       90000
# 346        3355  2021-01-01        FHC       E10       90000
# 347        3355  2021-01-01        6IW       E10       90000
# 348        3355  2021-01-01        C4A       E10       90000
# 349        3355  2021-01-01        HRW       E10       90000
# Group: 3581
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 609        3581  2023-01-01        HQW   CHENNAI      100000
# 610        3581  2023-01-01        FHY        C3          10
# 611        3581  2023-01-01        H6F        C1       23120
# 612        3581  2023-01-01        0YF        C1       23120
# 613        3581  2023-01-01        HQW        C1       23120
# 614        3581  2023-01-01        SPW        C2       23170
# 615        3581  2023-01-01        0YF        C2       23170
# Group: 3717
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 644        3717  2021-01-01        FHC        C2       23170
# 645        3717  2021-01-01        9ML        C1       23120
# 646        3717  2021-01-01        HOW        C1       23120
# 647        3717  2021-01-01        FHW        C1       23120
# 648        3717  2021-01-01        FHC        C1       23120
# 649        3717  2021-01-01        0YF        C1       23120
# 650        3717  2021-01-01        SPW        C1       23120
# Group: 3740
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 392        3740  2023-01-01        B4F  Bangaluru       99999
# 393        3740  2023-01-01        SVA  Bangaluru       99999
# 394        3740  2023-01-01        SVA  Bangaluru       99999
# 395        3740  2023-01-01        FHW  Bangaluru       99999
# 396        3740  2023-01-01        HQA  Bangaluru       99999
# 397        3740  2023-01-01        HRW  Bangaluru       99999
# 398        3740  2023-01-01        FHY  Bangaluru       99999
# Group: 3742
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 287        3742  2023-01-01        9ML        C1                23120
# 288        3742  2023-01-01        HQW        C2                23170
# 289        3742  2023-01-01        H6F        C3                   10
# 290        3742  2023-01-01        C4A        C4  1000000000000000000
# 291        3742  2023-01-01        FHB        C5                 2342
# 292        3742  2023-01-01        6IW        C6                23420
# 293        3742  2023-01-01        FHC        C7                  230
# Group: 3840
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 357        3840  2022-01-01        FHB   CHENNAI      100000
# 358        3840  2022-01-01        HQF        C3          10
# 359        3840  2022-01-01        SPW        C1       23120
# 360        3840  2022-01-01        B4F        C1       23120
# 361        3840  2022-01-01        H6F        C1       23120
# 362        3840  2022-01-01        HOW        C2       23170
# 363        3840  2022-01-01        9ML        C2       23170
# Group: 3875
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 189        3875  2023-01-01        S5F   CHENNAI      100000
# 190        3875  2023-01-01        SPW        C3          10
# 191        3875  2023-01-01        C4A        C1       23120
# 192        3875  2023-01-01        6IW        C1       23120
# 193        3875  2023-01-01        HOW        C1       23120
# 194        3875  2023-01-01        FHC        C2       23170
# 195        3875  2023-01-01        SVA        C2       23170
# Group: 4049
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 728        4049  2023-01-01        HQA  Bangaluru       99999
# 729        4049  2023-01-01        HQF  Bangaluru       99999
# 730        4049  2023-01-01        HQA  Bangaluru       99999
# 731        4049  2023-01-01        H6F  Bangaluru       99999
# 732        4049  2023-01-01        H6F  Bangaluru       99999
# 733        4049  2023-01-01        B4F  Bangaluru       99999
# 734        4049  2023-01-01        HQF  Bangaluru       99999
# Group: 4052
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 63        4052  2022-01-01        HRW        AP       79990
# 64        4052  2022-01-01        HQA        AP       79990
# 65        4052  2022-01-01        HQW        TS      800000
# 66        4052  2022-01-01        S5F        TS      800000
# 67        4052  2022-01-01        HQF        TS      800000
# 68        4052  2022-01-01        S5F        TS      800000
# 69        4052  2022-01-01        HQW        AP       79990
# Group: 4082
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 525        4082  2023-01-01        HQA   CHENNAI      100000
# 526        4082  2023-01-01        HQA        C3          10
# 527        4082  2023-01-01        HQW        C1       23120
# 528        4082  2023-01-01        FHW        C1       23120
# 529        4082  2023-01-01        FHB        C1       23120
# 530        4082  2023-01-01        SPW        C2       23170
# 531        4082  2023-01-01        0YF        C2       23170
# Group: 4094
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 532        4094  2023-01-01        FHC        C1       23120
# 533        4094  2023-01-01        FHC        C1       23120
# 534        4094  2023-01-01        HQW        C1       23120
# 535        4094  2021-01-01        C4A        C1       23120
# 536        4094  2021-01-01        HQF        C1       23120
# 537        4094  2021-01-01        FHB        C1       23120
# 538        4094  2021-01-01        6IW        C1       23120
# Group: 4109
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 266        4109  2022-01-01        HQA       E10       90000
# 267        4109  2022-01-01        FHB       E10       90000
# 268        4109  2022-01-01        0YF       E10       90000
# 269        4109  2022-01-01        S5F       E12      900000
# 270        4109  2022-01-01        HQF       E12      900000
# 271        4109  2022-01-01        HQW       E12      900000
# 272        4109  2022-01-01        FHC       E12      900000
# Group: 4178
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 623        4178  2023-01-01        SVA        C1                23120
# 624        4178  2023-01-01        HQW        C2                23170
# 625        4178  2023-01-01        HOW        C3                   10
# 626        4178  2023-01-01        0YF        C4  1000000000000000000
# 627        4178  2023-01-01        HRW        C5                 2342
# 628        4178  2023-01-01        FHY        C6                23420
# 629        4178  2023-01-01        H6F        C7                  230
# Group: 4331
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 679        4331  2022-01-01        FHY        C1       23120
# 680        4331  2022-01-01        HRW        C1       23120
# 681        4331  2022-01-01        B4F        C1       23120
# 682        4331  2022-01-01        FHW        C1       23120
# 683        4331  2022-01-01        FHB        C1       23120
# 684        4331  2022-01-01        SPW        C1       23120
# 685        4331  2022-01-01        FHC        C1       23120
# Group: 4342
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 539        4342  2021-01-01        B4F        C1                23120
# 540        4342  2021-01-01        HQW        C2                23170
# 541        4342  2021-01-01        H6F        C3                   10
# 542        4342  2021-01-01        HRW        C4  1000000000000000000
# 543        4342  2021-01-01        SVA        C5                 2342
# 544        4342  2021-01-01        HQW        C6                23420
# 545        4342  2021-01-01        SPW        C7                  230
# Group: 4346
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 14        4346  2021-01-01        FHY       E10       90000
# 15        4346  2021-01-01        HQA       E10       90000
# 16        4346  2021-01-01        HQA       E10       90000
# 17        4346  2021-01-01        SPW       E12      900000
# 18        4346  2021-01-01        HRW       E12      900000
# 19        4346  2021-01-01        FHW       E12      900000
# 20        4346  2021-01-01        S5F       E12      900000
# Group: 4419
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 945        4419  2023-01-01        B4F  Bangaluru       99999
# 946        4419  2023-01-01        B4F  Bangaluru       99999
# 947        4419  2023-01-01        FHW  Bangaluru       99999
# 948        4419  2023-01-01        FHC  Bangaluru       99999
# 949        4419  2023-01-01        9ML  Bangaluru       99999
# 950        4419  2023-01-01        HQF  Bangaluru       99999
# 951        4419  2023-01-01        FHY  Bangaluru       99999
# Group: 4440
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 973        4440  2021-01-01        HQW        C1       23120
# 974        4440  2021-01-01        9ML        C1       23120
# 975        4440  2021-01-01        FHC        C1       23120
# 976        4440  2021-01-01        S5F        C1       23120
# 977        4440  2021-01-01        FHC        C1       23120
# 978        4440  2021-01-01        HRW        C1       23120
# 979        4440  2021-01-01        C4A        C1       23120
# Group: 4456
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 511        4456  2023-01-01        HOW       E11        9000
# 512        4456  2023-01-01        HRW       E11        9000
# 513        4456  2023-01-01        FHC       E10       90000
# 514        4456  2023-01-01        HQA       E10       90000
# 515        4456  2023-01-01        HOW       E10       90000
# 516        4456  2023-01-01        FHY       E10       90000
# 517        4456  2023-01-01        FHY       E10       90000
# Group: 4530
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 126        4530  2021-01-01        H6F    jaipur      700000
# 127        4530  2021-01-01        0YF    jaipur      700000
# 128        4530  2021-01-01        HQA   jodhpur         700
# 129        4530  2021-01-01        SPW   jodhpur         700
# 130        4530  2021-01-01        FHC    jaipur      700000
# 131        4530  2021-01-01        B4F    jaipur      700000
# 132        4530  2021-01-01        H6F    jaipur      700000
# Group: 4539
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 931        4539  2023-01-01        FHY        AP       79990
# 932        4539  2023-01-01        FHW        AP       79990
# 933        4539  2023-01-01        HQA        TS      800000
# 934        4539  2023-01-01        HOW        TS      800000
# 935        4539  2023-01-01        HQW        TS      800000
# 936        4539  2023-01-01        SVA        TS      800000
# 937        4539  2023-01-01        SPW        AP       79990
# Group: 4642
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 259        4642  2022-01-01        HQA       E11        9000
# 260        4642  2022-01-01        SPW       E11        9000
# 261        4642  2022-01-01        FHW       E10       90000
# 262        4642  2022-01-01        FHB       E10       90000
# 263        4642  2022-01-01        B4F       E10       90000
# 264        4642  2022-01-01        FHY       E10       90000
# 265        4642  2022-01-01        HQA       E10       90000
# Group: 4807
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 630        4807  2023-01-01        H6F    jaipur      700000
# 631        4807  2023-01-01        FHW    jaipur      700000
# 632        4807  2023-01-01        C4A   jodhpur         700
# 633        4807  2023-01-01        B4F   jodhpur         700
# 634        4807  2023-01-01        B4F    jaipur      700000
# 635        4807  2023-01-01        HQW    jaipur      700000
# 636        4807  2023-01-01        0YF    jaipur      700000
# Group: 5025
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 819        5025  2023-01-01        SVA       E11        9000
# 820        5025  2023-01-01        HQW       E11        9000
# 821        5025  2023-01-01        HQF       E10       90000
# 822        5025  2023-01-01        SVA       E10       90000
# 823        5025  2023-01-01        FHB       E10       90000
# 824        5025  2023-01-01        H6F       E10       90000
# 825        5025  2023-01-01        HQW       E10       90000
# Group: 5069
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 217        5069  2021-01-01        HQF   jodhpur         700
# 218        5069  2021-01-01        FHW   jodhpur         700
# 219        5069  2021-01-01        FHC    jaipur      700000
# 220        5069  2021-01-01        HQA    Shimla         123
# 221        5069  2021-01-01        0YF   jodhpur         700
# 222        5069  2021-01-01        6IW   jodhpur         700
# 223        5069  2021-01-01        FHY    jaipur      700000
# 399        5069  2023-01-01        FHB        AP       79990
# 400        5069  2023-01-01        9ML        AP       79990
# 401        5069  2023-01-01        FHB        TS      800000
# 402        5069  2023-01-01        HQW        TS      800000
# 403        5069  2023-01-01        FHB        TS      800000
# 404        5069  2023-01-01        H6F        TS      800000
# 405        5069  2023-01-01        0YF        AP       79990
# Group: 5140
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 560        5140  2021-01-01        H6F  Bangaluru       99999
# 561        5140  2021-01-01        FHB  Bangaluru       99999
# 562        5140  2021-01-01        C4A  Bangaluru       99999
# 563        5140  2021-01-01        FHW  Bangaluru       99999
# 564        5140  2021-01-01        C4A  Bangaluru       99999
# 565        5140  2021-01-01        HQA  Bangaluru       99999
# 566        5140  2021-01-01        SVA  Bangaluru       99999
# Group: 5164
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 777        5164  2021-01-01        SVA        C3          10
# 778        5164  2021-01-01        SVA   CHENNAI      100000
# 779        5164  2021-01-01        SPW        C3          10
# 780        5164  2021-01-01        C4A        C1       23120
# 781        5164  2021-01-01        C4A        C1       23120
# 782        5164  2021-01-01        9ML        C1       23120
# 783        5164  2022-01-01        FHB        C2       23170
# Group: 5195
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 161        5195  2022-01-01        HRW       E10       90000
# 162        5195  2022-01-01        SVA       E10       90000
# 163        5195  2022-01-01        SPW       E10       90000
# 164        5195  2022-01-01        HOW       E12      900000
# 165        5195  2022-01-01        FHY       E12      900000
# 166        5195  2022-01-01        HQA       E12      900000
# 167        5195  2022-01-01        SPW       E12      900000
# Group: 5252
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 749        5252  2021-01-01        SPW       E10       90000
# 750        5252  2021-01-01        SVA       E10       90000
# 751        5252  2021-01-01        SVA       E10       90000
# 752        5252  2021-01-01        SVA       E12      900000
# 753        5252  2021-01-01        B4F       E12      900000
# 754        5252  2021-01-01        HQA       E12      900000
# 755        5252  2021-01-01        FHC       E12      900000
# Group: 5416
#     Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 77        5416  2023-01-01        FHY  Bangaluru       99999
# 78        5416  2023-01-01        SPW  Bangaluru       99999
# 79        5416  2023-01-01        SVA  Bangaluru       99999
# 80        5416  2023-01-01        FHW  Bangaluru       99999
# 81        5416  2023-01-01        HOW  Bangaluru       99999
# 82        5416  2023-01-01        H6F  Bangaluru       99999
# 83        5416  2023-01-01        FHB  Bangaluru       99999
# Group: 5447
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 28        5447  2021-01-01        6IW        C1       23120
# 29        5447  2021-01-01        S5F        C1       23120
# 30        5447  2021-01-01        C4A        C1       23120
# 31        5447  2021-01-01        HOW        C1       23120
# 32        5447  2021-01-01        FHB        C1       23120
# 33        5447  2021-01-01        0YF        C1       23120
# 34        5447  2021-01-01        9ML        C1       23120
# Group: 5632
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 714        5632  2023-01-01        HQF        AP       79990
# 715        5632  2023-01-01        FHW        AP       79990
# 716        5632  2023-01-01        HRW        TS      800000
# 717        5632  2023-01-01        S5F        TS      800000
# 718        5632  2023-01-01        HRW        TS      800000
# 719        5632  2023-01-01        B4F        TS      800000
# 720        5632  2023-01-01        SPW        AP       79990
# Group: 5665
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 280        5665  2022-01-01        0YF        C1       23120
# 281        5665  2022-01-01        B4F        C1       23120
# 282        5665  2022-01-01        6IW        C1       23120
# 283        5665  2022-01-01        C4A        C1       23120
# 284        5665  2022-01-01        HQF        C1       23120
# 285        5665  2022-01-01        C4A        C1       23120
# 286        5665  2023-01-01        FHY        C1       23120
# Group: 5701
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 315        5701  2023-01-01        HQA        C1       23120
# 316        5701  2023-01-01        HOW       E10       90000
# 317        5701  2023-01-01        HRW       E10       90000
# 318        5701  2023-01-01        FHY       E10       90000
# 319        5701  2023-01-01        0YF       E10       90000
# 320        5701  2023-01-01        HQW       E10       90000
# 321        5701  2021-01-01        SPW       E11        9000
# Group: 5756
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 168        5756  2022-01-01        H6F       E10       90000
# 169        5756  2022-01-01        HQW       E10       90000
# 170        5756  2022-01-01        6IW       E10       90000
# 171        5756  2022-01-01        C4A       E10       90000
# 172        5756  2022-01-01        HRW       E10       90000
# 173        5756  2022-01-01        HOW       E10       90000
# 174        5756  2022-01-01        FHW       E11        9000
# Group: 5960
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 329        5960  2021-01-01        0YF       E10       90000
# 330        5960  2021-01-01        FHY       E10       90000
# 331        5960  2021-01-01        FHW       E10       90000
# 332        5960  2021-01-01        HQF       E12      900000
# 333        5960  2021-01-01        6IW       E12      900000
# 334        5960  2021-01-01        FHB       E12      900000
# 335        5960  2021-01-01        FHY       E12      900000
# Group: 6102
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 42        6102  2022-01-01        S5F    jaipur      700000
# 43        6102  2022-01-01        HQA    jaipur      700000
# 44        6102  2022-01-01        6IW   jodhpur         700
# 45        6102  2022-01-01        B4F   jodhpur         700
# 46        6102  2022-01-01        HQW    jaipur      700000
# 47        6102  2022-01-01        0YF    jaipur      700000
# 48        6102  2022-01-01        B4F    jaipur      700000
# Group: 6299
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 455        6299  2021-01-01        HOW        C1                23120
# 456        6299  2021-01-01        SPW        C2                23170
# 457        6299  2021-01-01        FHY        C3                   10
# 458        6299  2021-01-01        HRW        C4  1000000000000000000
# 459        6299  2021-01-01        S5F        C5                 2342
# 460        6299  2021-01-01        FHW        C6                23420
# 461        6299  2021-01-01        SVA        C7                  230
# Group: 6322
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 735        6322  2023-01-01        HQA       E10       90000
# 736        6322  2023-01-01        SPW       E10       90000
# 737        6322  2023-01-01        SPW       E10       90000
# 738        6322  2023-01-01        C4A       E10       90000
# 739        6322  2023-01-01        6IW       E10       90000
# 740        6322  2023-01-01        FHC       E10       90000
# 741        6322  2023-01-01        FHC       E11        9000
# Group: 6325
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 231        6325  2021-01-01        6IW        AP       79990
# 232        6325  2021-01-01        B4F        AP       79990
# 233        6325  2021-01-01        FHY        TS      800000
# 234        6325  2021-01-01        FHB        TS      800000
# 235        6325  2021-01-01        C4A        TS      800000
# 236        6325  2021-01-01        6IW        TS      800000
# 237        6325  2021-01-01        0YF        AP       79990
# Group: 6347
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 385        6347  2022-01-01        SVA   jodhpur         700
# 386        6347  2022-01-01        HQA   jodhpur         700
# 387        6347  2022-01-01        6IW    jaipur      700000
# 388        6347  2022-01-01        B4F    Shimla         123
# 389        6347  2022-01-01        FHY   jodhpur         700
# 390        6347  2022-01-01        HQF   jodhpur         700
# 391        6347  2022-01-01        SVA    jaipur      700000
# Group: 6400
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 693        6400  2022-01-01        H6F    jaipur      700000
# 694        6400  2022-01-01        FHC    jaipur      700000
# 695        6400  2022-01-01        HOW   jodhpur         700
# 696        6400  2022-01-01        0YF   jodhpur         700
# 697        6400  2022-01-01        FHB    jaipur      700000
# 698        6400  2022-01-01        FHW    jaipur      700000
# 699        6400  2022-01-01        FHW    jaipur      700000
# Group: 6440
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 378        6440  2022-01-01        FHW    jaipur      700000
# 379        6440  2022-01-01        0YF    jaipur      700000
# 380        6440  2022-01-01        SVA   jodhpur         700
# 381        6440  2022-01-01        SPW   jodhpur         700
# 382        6440  2022-01-01        HQW    jaipur      700000
# 383        6440  2022-01-01        FHW    jaipur      700000
# 384        6440  2022-01-01        FHC    jaipur      700000
# Group: 6463
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 854        6463  2021-01-01        6IW    jaipur      700000
# 855        6463  2021-01-01        C4A    jaipur      700000
# 856        6463  2021-01-01        FHY   jodhpur         700
# 857        6463  2021-01-01        HOW   jodhpur         700
# 858        6463  2021-01-01        H6F    jaipur      700000
# 859        6463  2021-01-01        FHB    jaipur      700000
# 860        6463  2021-01-01        FHW    jaipur      700000
# Group: 6638
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 882        6638  2021-01-01        HRW        AP       79990
# 883        6638  2021-01-01        H6F        AP       79990
# 884        6638  2021-01-01        FHW        TS      800000
# 885        6638  2021-01-01        0YF        TS      800000
# 886        6638  2021-01-01        HQW        TS      800000
# 887        6638  2022-01-01        SPW        TS      800000
# 888        6638  2022-01-01        HQW        AP       79990
# Group: 6646
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 581        6646  2022-01-01        HQA  Bangaluru       99999
# 582        6646  2022-01-01        6IW  Bangaluru       99999
# 583        6646  2022-01-01        C4A  Bangaluru       99999
# 584        6646  2022-01-01        S5F  Bangaluru       99999
# 585        6646  2022-01-01        B4F  Bangaluru       99999
# 586        6646  2022-01-01        SVA  Bangaluru       99999
# 587        6646  2022-01-01        S5F  Bangaluru       99999
# Group: 6751
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 889        6751  2022-01-01        H6F  Bangaluru       99999
# 890        6751  2022-01-01        SVA  Bangaluru       99999
# 891        6751  2022-01-01        SVA  Bangaluru       99999
# 892        6751  2022-01-01        HQF  Bangaluru       99999
# 893        6751  2022-01-01        HOW  Bangaluru       99999
# 894        6751  2022-01-01        FHC  Bangaluru       99999
# 895        6751  2022-01-01        0YF  Bangaluru       99999
# Group: 6786
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 105        6786  2023-01-01        HQF   CHENNAI      100000
# 106        6786  2023-01-01        6IW        C3          10
# 107        6786  2023-01-01        0YF        C1       23120
# 108        6786  2023-01-01        HQW        C1       23120
# 109        6786  2021-01-01        HQA        C1       23120
# 110        6786  2021-01-01        B4F        C2       23170
# 111        6786  2021-01-01        HQW        C2       23170
# Group: 6819
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 203        6819  2023-01-01        S5F        C1                23120
# 204        6819  2023-01-01        9ML        C2                23170
# 205        6819  2023-01-01        HQW        C3                   10
# 206        6819  2023-01-01        0YF        C4  1000000000000000000
# 207        6819  2023-01-01        FHY        C5                 2342
# 208        6819  2023-01-01        S5F        C6                23420
# 209        6819  2023-01-01        FHY        C7                  230
# Group: 6848
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 336        6848  2021-01-01        HQW       E10       90000
# 337        6848  2021-01-01        SVA       E10       90000
# 338        6848  2021-01-01        HQF       E10       90000
# 339        6848  2021-01-01        6IW       E10       90000
# 340        6848  2021-01-01        HOW       E10       90000
# 341        6848  2021-01-01        HQF       E10       90000
# 342        6848  2021-01-01        HOW       E11        9000
# Group: 6986
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 910        6986  2022-01-01        9ML       E10       90000
# 911        6986  2022-01-01        FHW       E10       90000
# 912        6986  2022-01-01        HRW       E10       90000
# 913        6986  2022-01-01        0YF       E12      900000
# 914        6986  2022-01-01        HRW       E12      900000
# 915        6986  2022-01-01        HQF       E12      900000
# 916        6986  2022-01-01        C4A       E12      900000
# Group: 7052
#     Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 56        7052  2022-01-01        C4A  Bangaluru       99999
# 57        7052  2022-01-01        FHB  Bangaluru       99999
# 58        7052  2022-01-01        FHC  Bangaluru       99999
# 59        7052  2022-01-01        HOW  Bangaluru       99999
# 60        7052  2022-01-01        SVA  Bangaluru       99999
# 61        7052  2022-01-01        S5F  Bangaluru       99999
# 62        7052  2022-01-01        H6F  Bangaluru       99999
# Group: 7092
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 805        7092  2022-01-01        FHB       E10       90000
# 806        7092  2022-01-01        SPW       E10       90000
# 807        7092  2022-01-01        HQF       E10       90000
# 808        7092  2022-01-01        S5F       E12      900000
# 809        7092  2022-01-01        S5F       E12      900000
# 810        7092  2022-01-01        FHY       E12      900000
# 811        7092  2022-01-01        FHB       E12      900000
# Group: 7192
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 252        7192  2022-01-01        FHY       E10       90000
# 253        7192  2022-01-01        SPW       E10       90000
# 254        7192  2022-01-01        HOW       E10       90000
# 255        7192  2022-01-01        HOW       E10       90000
# 256        7192  2022-01-01        FHB       E10       90000
# 257        7192  2022-01-01        SPW       E10       90000
# 258        7192  2022-01-01        FHW       E11        9000
# Group: 7193
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 371        7193  2022-01-01        6IW        C1                23120
# 372        7193  2022-01-01        FHC        C2                23170
# 373        7193  2022-01-01        HQW        C3                   10
# 374        7193  2022-01-01        HQF        C4  1000000000000000000
# 375        7193  2022-01-01        SPW        C5                 2342
# 376        7193  2022-01-01        HQF        C6                23420
# 377        7193  2022-01-01        FHB        C7                  230
# Group: 7220
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 791        7220  2022-01-01        SVA        C1       23120
# 792        7220  2022-01-01        9ML       E10       90000
# 793        7220  2022-01-01        HQA       E10       90000
# 794        7220  2022-01-01        FHC       E10       90000
# 795        7220  2022-01-01        FHY       E10       90000
# 796        7220  2022-01-01        B4F       E10       90000
# 797        7220  2022-01-01        FHC       E11        9000
# Group: 7236
#     Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 35        7236  2021-01-01        0YF        C1                23120
# 36        7236  2021-01-01        FHB        C2                23170
# 37        7236  2022-01-01        FHW        C3                   10
# 38        7236  2022-01-01        9ML        C4  1000000000000000000
# 39        7236  2022-01-01        HOW        C5                 2342
# 40        7236  2022-01-01        FHB        C6                23420
# 41        7236  2022-01-01        6IW        C7                  230
# Group: 7237
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 91        7237  2023-01-01        HQW       E11        9000
# 92        7237  2023-01-01        S5F       E11        9000
# 93        7237  2023-01-01        FHW       E10       90000
# 94        7237  2023-01-01        C4A       E10       90000
# 95        7237  2023-01-01        H6F       E10       90000
# 96        7237  2023-01-01        SVA       E10       90000
# 97        7237  2023-01-01        S5F       E10       90000
# Group: 7260
# ...
# 441        8213  2021-01-01        HQA   CHENNAI      100000
# 442        8213  2021-01-01        SPW        C3          10
# 443        8213  2021-01-01        HQF        C1       23120
# 444        8213  2021-01-01        HQF        C1       23120
# 445        8213  2021-01-01        B4F        C1       23120
# 446        8213  2021-01-01        FHY        C2       23170
# 447        8213  2021-01-01        HQF        C2       23170
# Group: 8298
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 84        8298  2023-01-01        SPW       E10       90000
# 85        8298  2023-01-01        FHC       E10       90000
# 86        8298  2023-01-01        HQW       E10       90000
# 87        8298  2023-01-01        HOW       E10       90000
# 88        8298  2023-01-01        HQA       E10       90000
# 89        8298  2023-01-01        SPW       E10       90000
# 90        8298  2023-01-01        SVA       E11        9000
# Group: 8314
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 448        8314  2021-01-01        HQA        C1       23120
# 449        8314  2021-01-01        HQW        C1       23120
# 450        8314  2021-01-01        HQF        C1       23120
# 451        8314  2021-01-01        9ML        C1       23120
# 452        8314  2021-01-01        H6F        C1       23120
# 453        8314  2021-01-01        0YF        C1       23120
# 454        8314  2021-01-01        H6F        C1       23120
# Group: 8330
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 301        8330  2023-01-01        0YF   jodhpur         700
# 302        8330  2023-01-01        6IW   CHENNAI      100000
# 303        8330  2023-01-01        B4F        C3          10
# 304        8330  2023-01-01        HRW        C1       23120
# 305        8330  2023-01-01        C4A        C1       23120
# 306        8330  2023-01-01        9ML        C1       23120
# 307        8330  2023-01-01        HOW        C2       23170
# Group: 8380
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 462        8380  2021-01-01        0YF    jaipur      700000
# 463        8380  2021-01-01        H6F    jaipur      700000
# 464        8380  2021-01-01        HQF   jodhpur         700
# 465        8380  2022-01-01        0YF   jodhpur         700
# 466        8380  2022-01-01        HQF    jaipur      700000
# 467        8380  2022-01-01        B4F    jaipur      700000
# 468        8380  2022-01-01        B4F    jaipur      700000
# Group: 8384
#     Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 49        8384  2022-01-01        HQF   jodhpur         700
# 50        8384  2022-01-01        SVA   jodhpur         700
# 51        8384  2022-01-01        H6F    jaipur      700000
# 52        8384  2022-01-01        6IW    Shimla         123
# 53        8384  2022-01-01        C4A   jodhpur         700
# 54        8384  2022-01-01        C4A   jodhpur         700
# 55        8384  2022-01-01        FHB    jaipur      700000
# Group: 8438
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 742        8438  2023-01-01        B4F       E11        9000
# 743        8438  2023-01-01        FHC       E11        9000
# 744        8438  2023-01-01        6IW       E10       90000
# 745        8438  2023-01-01        FHC       E10       90000
# 746        8438  2023-01-01        HQA       E10       90000
# 747        8438  2023-01-01        C4A       E10       90000
# 748        8438  2023-01-01        B4F       E10       90000
# Group: 8707
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 406        8707  2023-01-01        6IW        AP       79990
# 407        8707  2023-01-01        9ML        AP       79990
# 408        8707  2023-01-01        FHY        TS      800000
# 409        8707  2023-01-01        HQA        TS      800000
# 410        8707  2023-01-01        HRW        TS      800000
# 411        8707  2023-01-01        FHC        TS      800000
# 412        8707  2023-01-01        HRW        AP       79990
# Group: 8710
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 658        8710  2021-01-01        HQW       E11        9000
# 659        8710  2021-01-01        B4F       E11        9000
# 660        8710  2021-01-01        HOW       E10       90000
# 661        8710  2021-01-01        0YF       E10       90000
# 662        8710  2021-01-01        H6F       E10       90000
# 663        8710  2021-01-01        C4A       E10       90000
# 664        8710  2021-01-01        HQF       E10       90000
# Group: 8817
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 483        8817  2022-01-01        HRW        C1       23120
# 484        8817  2022-01-01        FHC       E10       90000
# 485        8817  2022-01-01        FHC       E10       90000
# 486        8817  2022-01-01        HQW       E10       90000
# 487        8817  2022-01-01        FHW       E10       90000
# 488        8817  2022-01-01        HQW       E10       90000
# 489        8817  2022-01-01        HQW       E11        9000
# Group: 8855
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 98         8855  2023-01-01        SPW       E10       90000
# 99         8855  2023-01-01        HQW       E10       90000
# 100        8855  2023-01-01        H6F       E10       90000
# 101        8855  2023-01-01        FHW       E12      900000
# 102        8855  2023-01-01        S5F       E12      900000
# 103        8855  2023-01-01        HOW       E12      900000
# 104        8855  2023-01-01        FHW       E12      900000
# Group: 8861
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 546        8861  2021-01-01        9ML    jaipur      700000
# 547        8861  2021-01-01        H6F    jaipur      700000
# 548        8861  2021-01-01        H6F   jodhpur         700
# 549        8861  2021-01-01        B4F   jodhpur         700
# 550        8861  2021-01-01        0YF    jaipur      700000
# 551        8861  2021-01-01        HQW    jaipur      700000
# 552        8861  2021-01-01        6IW    jaipur      700000
# Group: 8901
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 364        8901  2022-01-01        FHY        C1       23120
# 365        8901  2022-01-01        SVA        C1       23120
# 366        8901  2022-01-01        SVA        C1       23120
# 367        8901  2022-01-01        C4A        C1       23120
# 368        8901  2022-01-01        FHY        C1       23120
# 369        8901  2022-01-01        HRW        C1       23120
# 370        8901  2022-01-01        B4F        C1       23120
# Group: 8912
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 567        8912  2021-01-01        9ML        AP       79990
# 568        8912  2021-01-01        H6F        AP       79990
# 569        8912  2022-01-01        FHB        TS      800000
# 570        8912  2022-01-01        SPW        TS      800000
# 571        8912  2022-01-01        0YF        TS      800000
# 572        8912  2022-01-01        0YF        TS      800000
# 573        8912  2022-01-01        S5F        AP       79990
# Group: 9000
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 756        9000  2021-01-01        HQF       E10       90000
# 757        9000  2021-01-01        B4F       E10       90000
# 758        9000  2021-01-01        FHW       E10       90000
# 759        9000  2021-01-01        HQA       E10       90000
# 760        9000  2021-01-01        H6F       E10       90000
# 761        9000  2021-01-01        6IW       E10       90000
# 762        9000  2021-01-01        H6F       E11        9000
# Group: 9029
#      Shipment_n  Gate_Out_D Model_Code City_Code           Base_Freig
# 119        9029  2021-01-01        FHB        C1                23120
# 120        9029  2021-01-01        C4A        C2                23170
# 121        9029  2021-01-01        9ML        C3                   10
# 122        9029  2021-01-01        HRW        C4  1000000000000000000
# 123        9029  2021-01-01        6IW        C5                 2342
# 124        9029  2021-01-01        HQF        C6                23420
# 125        9029  2021-01-01        HQA        C7                  230
# Group: 9082
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 665        9082  2021-01-01        6IW       E10       90000
# 666        9082  2021-01-01        FHY       E10       90000
# 667        9082  2021-01-01        HQA       E10       90000
# 668        9082  2021-01-01        FHY       E12      900000
# 669        9082  2021-01-01        C4A       E12      900000
# 670        9082  2021-01-01        S5F       E12      900000
# 671        9082  2021-01-01        HRW       E12      900000
# Group: 9126
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 861        9126  2021-01-01        HQW   jodhpur         700
# 862        9126  2021-01-01        H6F   jodhpur         700
# 863        9126  2021-01-01        SPW    jaipur      700000
# 864        9126  2021-01-01        FHY    Shimla         123
# 865        9126  2021-01-01        S5F   jodhpur         700
# 866        9126  2021-01-01        FHY   jodhpur         700
# 867        9126  2021-01-01        HQF    jaipur      700000
# Group: 9181
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 518        9181  2023-01-01        FHW       E10       90000
# 519        9181  2023-01-01        HQW       E10       90000
# 520        9181  2023-01-01        SPW       E10       90000
# 521        9181  2023-01-01        HOW       E12      900000
# 522        9181  2023-01-01        SPW       E12      900000
# 523        9181  2023-01-01        SPW       E12      900000
# 524        9181  2023-01-01        H6F       E12      900000
# Group: 9290
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 763        9290  2021-01-01        0YF       E11        9000
# 764        9290  2021-01-01        6IW       E11        9000
# 765        9290  2021-01-01        HQF       E10       90000
# 766        9290  2021-01-01        B4F       E10       90000
# 767        9290  2021-01-01        HQW       E10       90000
# 768        9290  2021-01-01        6IW       E10       90000
# 769        9290  2021-01-01        H6F       E10       90000
# Group: 9378
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 798        9378  2022-01-01        FHB       E11        9000
# 799        9378  2022-01-01        0YF       E11        9000
# 800        9378  2022-01-01        SPW       E10       90000
# 801        9378  2022-01-01        0YF       E10       90000
# 802        9378  2022-01-01        FHB       E10       90000
# 803        9378  2022-01-01        HOW       E10       90000
# 804        9378  2022-01-01        FHW       E10       90000
# Group: 9418
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 574        9418  2022-01-01        S5F        AP       79990
# 575        9418  2022-01-01        HQW        AP       79990
# 576        9418  2022-01-01        SVA        TS      800000
# 577        9418  2022-01-01        9ML        TS      800000
# 578        9418  2022-01-01        FHB        TS      800000
# 579        9418  2022-01-01        SPW        TS      800000
# 580        9418  2022-01-01        9ML        AP       79990
# Group: 9493
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 980        9493  2021-01-01        HRW       E10       90000
# 981        9493  2021-01-01        HQW       E10       90000
# 982        9493  2021-01-01        FHC       E10       90000
# 983        9493  2021-01-01        FHW       E10       90000
# 984        9493  2021-01-01        0YF       E10       90000
# 985        9493  2021-01-01        HQW       E11        9000
# 986        9493  2021-01-01        B4F       E11        9000
# Group: 9564
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 637        9564  2023-01-01        HQF   jodhpur         700
# 638        9564  2021-01-01        9ML   CHENNAI      100000
# 639        9564  2021-01-01        HQA        C3          10
# 640        9564  2021-01-01        HQF        C1       23120
# 641        9564  2021-01-01        SVA        C1       23120
# 642        9564  2021-01-01        FHY        C1       23120
# 643        9564  2021-01-01        HOW        C2       23170
# Group: 9668
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 420        9668  2023-01-01        HOW       E10       90000
# 421        9668  2023-01-01        HQA       E10       90000
# 422        9668  2023-01-01        HQW       E10       90000
# 423        9668  2023-01-01        6IW       E10       90000
# 424        9668  2023-01-01        SPW       E10       90000
# 425        9668  2023-01-01        FHC       E10       90000
# 426        9668  2021-01-01        FHC       E11        9000
# Group: 9754
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 350        9754  2021-01-01        B4F       E10       90000
# 351        9754  2021-01-01        HOW       E10       90000
# 352        9754  2021-01-01        H6F       E10       90000
# 353        9754  2021-01-01        6IW       E12      900000
# 354        9754  2021-01-01        HQF       E12      900000
# 355        9754  2021-01-01        FHY       E12      900000
# 356        9754  2022-01-01        HQW       E12      900000
# Group: 9762
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 924        9762  2023-01-01        SPW        AP       79990
# 925        9762  2023-01-01        FHY        AP       79990
# 926        9762  2023-01-01        9ML        TS      800000
# 927        9762  2023-01-01        HQA        TS      800000
# 928        9762  2023-01-01        HQW        TS      800000
# 929        9762  2023-01-01        SVA        TS      800000
# 930        9762  2023-01-01        FHW        AP       79990
# Group: 9853
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 308        9853  2023-01-01        FHB        C2       23170
# 309        9853  2023-01-01        FHC        C1       23120
# 310        9853  2023-01-01        C4A        C1       23120
# 311        9853  2023-01-01        6IW        C1       23120
# 312        9853  2023-01-01        6IW        C1       23120
# 313        9853  2023-01-01        FHB        C1       23120
# 314        9853  2023-01-01        FHB        C1       23120
# Group: 9859
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 245        9859  2021-01-01        HRW  Bangaluru       99999
# 246        9859  2021-01-01        9ML  Bangaluru       99999
# 247        9859  2021-01-01        HOW  Bangaluru       99999
# 248        9859  2021-01-01        FHY  Bangaluru       99999
# 249        9859  2022-01-01        HQW  Bangaluru       99999
# 250        9859  2022-01-01        S5F  Bangaluru       99999
# 251        9859  2022-01-01        B4F  Bangaluru       99999
# Group: 9963
#      Shipment_n  Gate_Out_D Model_Code  City_Code  Base_Freig
# 868        9963  2021-01-01        HQF  Bangaluru       99999
# 869        9963  2021-01-01        H6F  Bangaluru       99999
# 870        9963  2021-01-01        HRW  Bangaluru       99999
# 871        9963  2021-01-01        FHB  Bangaluru       99999
# 872        9963  2021-01-01        H6F  Bangaluru       99999
# 873        9963  2021-01-01        S5F  Bangaluru       99999
# 874        9963  2021-01-01        SVA  Bangaluru       99999
# Group: 9970
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 140        9970  2021-01-01        SPW        C2       23170
# 141        9970  2021-01-01        C4A        C1       23120
# 142        9970  2021-01-01        HQA        C1       23120
# 143        9970  2021-01-01        HOW        C1       23120
# 144        9970  2022-01-01        FHB        C1       23120
# 145        9970  2022-01-01        HRW        C1       23120
# 146        9970  2022-01-01        HOW        C1       23120
# Group: 9976
#      Shipment_n  Gate_Out_D Model_Code City_Code  Base_Freig
# 826        9976  2023-01-01        6IW       E10       90000
# 827        9976  2023-01-01        C4A       E10       90000
# 828        9976  2023-01-01        H6F       E10       90000
# 829        9976  2023-01-01        FHW       E12      900000
# 830        9976  2023-01-01        C4A       E12      900000
# 831        9976  2023-01-01        HRW       E12      900000
# 832        9976  2023-01-01        HQW       E12      900000
